# %%
import numpy as np
import pandas as pd
import random
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Conv2D, Dense, MaxPooling2D
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import mnist

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
print(X_train.shape)
# Out:
# (60000, 28, 28)

# %%
X_train[0].min(), X_train[0].max()
# Out:
# (0, 255)

# %%
X_train = (X_train - 0.0) / (255.0 - 0.0)
X_test = (X_test - 0.0) / (255.0 - 0.0)
X_train[0].min(), X_train[0].max()
# Out:
# (0.0, 1.0)

# %%
def plot_digit(image, digit, plt, i):
    plt.subplot(4, 5, i + 1)
    plt.imshow(image, cmap=plt.get_cmap('gray'))
    plt.title(f"Digit: {digit}")
    plt.xticks([])
    plt.yticks([])

plt.figure(figsize=(16, 10))
for i in range(20):
    plot_digit(X_train[i], y_train[i], plt, i)
plt.show()

# %%
X_train = X_train.reshape((X_train.shape + (1,)))
X_test = X_test.reshape((X_test.shape + (1,)))

# %%
y_train[0:20]
# Out:
# array([5, 0, 4, 1, 9, 2, 1, 3, 1, 4, 3, 5, 3, 6, 1, 7, 2, 8, 6, 9],
#       dtype=uint8)

# %%
model = Sequential([
    Conv2D(32, (3, 3), activation="relu", input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(100, activation="relu"),
    Dense(10, activation="softmax")
])

# %%
optimizer = SGD(learning_rate=0.01, momentum=0.9)
model.compile(
    optimizer=optimizer,
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2  (None, 13, 13, 32)        0
#  D)
#
#  flatten (Flatten)           (None, 5408)              0
#
#  dense (Dense)               (None, 100)               540900
#
#  dense_1 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 542230 (2.07 MB)
# Trainable params: 542230 (2.07 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model_log = model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.2) # Add validation split here
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 37s 24ms/step - loss: 0.2656 - accuracy: 0.9194 - val_loss: 0.1236 - val_accuracy: 0.9648
# Epoch 2/10
# 1500/1500 [==============================] - 33s 22ms/step - loss: 0.0883 - accuracy: 0.9729 - val_loss: 0.0741 - val_accuracy: 0.9780
# Epoch 3/10
# 1500/1500 [==============================] - 32s 21ms/step - loss: 0.0577 - accuracy: 0.9826 - val_loss: 0.0690 - val_accuracy: 0.9789
# Epoch 4/10
# 1500/1500 [==============================] - 31s 21ms/step - loss: 0.0408 - accuracy: 0.9876 - val_loss: 0.0575 - val_accuracy: 0.9833
# Epoch 5/10
# 1500/1500 [==============================] - 32s 22ms/step - loss: 0.0297 - accuracy: 0.9908 - val_loss: 0.0578 - val_accuracy: 0.9837
# Epoch 6/10
# 1500/1500 [==============================] - 31s 21ms/step - loss: 0.0220 - accuracy: 0.9929 - val_loss: 0.0533 - val_accuracy: 0.9853
# Epoch 7/10
# 1500/1500 [==============================] - 35s 24ms/step - loss: 0.0156 - accuracy: 0.9953 - val_loss: 0.0508 - val_accuracy: 0.9860
# Epoch 8/10
# 1500/1500 [==============================] - 32s 22ms/step - loss: 0.0117 - accuracy: 0.9965 - val_loss: 0.0512 - val_accuracy: 0.9859
# Epoch 9/10
# 1500/1500 [==============================] - 35s 24ms/step - loss: 0.0086 - accuracy: 0.9976 - val_loss: 0.0558 - val_accuracy: 0.9856
# Epoch 10/10
# 1500/1500 [==============================] - 32s 21ms/step - loss: 0.0056 - accuracy: 0.9988 - val_loss: 0.0608 - val_accuracy: 0.9838

# %%
plt.figure(figsize=(16, 10))
for i in range(20):
    image = random.choice(X_test).squeeze()
    digit = np.argmax(model.predict(image.reshape((1, 28, 28, 1)))[0], axis=-1)
    plot_digit(image, digit, plt, i)
plt.show()
# Out:
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step

# %%
predictions = np.argmax(model.predict(X_test), axis=-1)
print("Accuracy:", accuracy_score(y_test, predictions))
# Out:
# 313/313 [==============================] - 2s 6ms/step
# Accuracy: 0.9861

# %%
score = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])#Test loss: 0.0296396646054
print('Test accuracy:', score[1]) #Test accuracy: 0.9904
# Out:
# Test loss: 0.0476631261408329
# Test accuracy: 0.9861000180244446

# %%
import os
fig = plt.figure()
plt.subplot(2, 1, 1)
plt.plot(model_log.history['accuracy'])
plt.plot(model_log.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')
plt.subplot(2, 1, 2)
plt.plot(model_log.history['loss'])
plt.plot(model_log.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.tight_layout()

plt.show()

# %%
import tensorflow as tf
from tensorflow import keras
model = keras.Sequential([
    keras.layers.Dense(128, activation='relu', input_shape=(784,)),
    keras.layers.Dense(10, activation='softmax')
])
model_json = model.to_json()
with open("model_digit.json", "w") as json_file:
    json_file.write(model_json)
model.save_weights("model_digit.h5")
print("Saved model to disk")
# Out:
# Saved model to disk
